# %% [markdown]
# Predict trophies
# based on cards, achievements,badges, total games, total donations

# %%
import pandas as pd
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier¶

# %%
import os
import json
import numpy as np
import pandas as pd

# Set the file path for the JSON file
json_file_path = os.path.join('..', 'Resources', 'combined_player_tags.json')

# Check if the file exists
if os.path.exists(json_file_path):
    # Open and load the JSON data
    with open(json_file_path) as fp:
        player_data = json.load(fp)
        # Process player_data as needed
else:
    print("File not found:", json_file_path)

# %%
import pandas as pd

# File path to the CSV file
csv_file_path = os.path.join('..', 'Resources', 'combined_player_tags.csv')

# Columns to drop
columns_to_drop = ['player/tag', 'data/currentPathofLegendSeasonResult', 
                   'data/lastPathofLegendSeasonResult', 'data/lastPathofLegendSeasonResult/rank']

# Load the CSV file into a DataFrame
player_data_wide_df = pd.read_csv(csv_file_path)

# Dropping columns
player_data_wide_df.drop(columns=columns_to_drop, inplace=True)

# Displaying the DataFrame
print(player_data_wide_df.head())
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[7], line 11
#       7 columns_to_drop = ['player/tag', 'data/currentPathofLegendSeasonResult',
#       8                    'data/lastPathofLegendSeasonResult', 'data/lastPathofLegendSeasonResult/rank']
#      10 # Load the CSV file into a DataFrame
# ---> 11 player_data_wide_df = pd.read_csv(csv_file_path)
#      13 # Dropping columns
#      14 player_data_wide_df.drop(columns=columns_to_drop, inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %%
player_data_wide_df = pd.json_normalize(player_data)
player_data_wide_df
# Out:
#         player_tag    data.tag        data.name  data.expLevel  data.trophies  \
# 0         %23LV0LV      #LV0LV         FAJRI JR              5            676
# 1        %238R80YP     #8R80YP  <c7>omeganike</             37           5492
# 2         %23R0VJQ      #R0VJQ         jonas123             10           1954
# 3     %23JRRULRR9C  #JRRULRR9C           samuel              4            377
# 4     %23QRJVULQQ9  #QRJVULQQ9              ash              8           3775
# ...            ...         ...              ...            ...            ...
# 9385  %23U8QYJ92L9  #U8QYJ92L9              lin              2            150
# 9386    %2390CCQLL    #90CCQLL           Bodzio              9           2857
# 9387      %23GYY8V      #GYY8V        Kingaj282             25           3800
# 9388  %23P8CL9JVUQ  #P8CL9JVUQ               mv              3            278
# 9389  %23L9QG080Q9  #L9QG080Q9         luca2724             27           5117
#
# ...

# %%
drop player_tag
drop data.currentPathofLegendSeasonResult
drop data.lastPathofLegendSeasonResult
drop data.lastPathofLegendSeasonResult.rank

drop data.achievements.[].completionInfo
drop data.badges.[].iconUrls.large
drop data.cards.[].iconUrls.medium
drop data.currentDeck.[].iconUrls.evolutionMedium
drop data.currentDeck.[].iconUrls.medium
drop data.currentFavouriteCard.[].iconUrls.evolutionMedium
drop data.currentFavouriteCard.[].iconUrls.medium
drop data.supportCards.[].iconUrls.medium

# %%
columns_to_drop = ['player_tag', 'data.currentPathofLegendSeasonResult', 'data.lastPathofLegendSeasonResult', 
                   'data.lastPathofLegendSeasonResult.rank']

player_data_wide_df.drop(columns=columns_to_drop, inplace=True)
player_data_wide_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 4
#       1 columns_to_drop = ['player_tag', 'data.currentPathofLegendSeasonResult', 'data.lastPathofLegendSeasonResult',
#       2                    'data.lastPathofLegendSeasonResult.rank']
# ----> 4 player_data_wide_df.drop(columns=columns_to_drop, inplace=True)
#       5 player_data_wide_df.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...
