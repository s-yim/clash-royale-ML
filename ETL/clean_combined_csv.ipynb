# %%
import os
import pandas as pd

# File path to the CSV file
csv_file_path = os.path.join('..', 'Resources', 'combined_player_tags1.csv')

# Columns to drop
columns_to_drop = ['/player_tag', '/data/currentPathOfLegendSeasonResult', 
                   '/data/lastPathOfLegendSeasonResult', '/data/lastPathOfLegendSeasonResult/rank']

# Load the CSV file into a DataFrame
player_data_wide_df = pd.read_csv(csv_file_path)

# Dropping columns
player_data_wide_df.drop(columns=columns_to_drop, inplace=True)

# Displaying the DataFrame
player_data_wide_df.head()
# Out:
# C:\Users\sungm\AppData\Local\Temp\ipykernel_61600\747014021.py:12: DtypeWarning: Columns (182,185,188,191,194,197,200,203,206,209,212,215,224,227,230,233,236,239,242,245,248,251,254,257,260,263,266,269,922,934,946,958,970,982,994) have mixed types. Specify dtype option on import or set low_memory=False.
#   player_data_wide_df = pd.read_csv(csv_file_path)
#    /data/achievements/0/completionInfo /data/achievements/0/info  \
# 0                                  NaN               Join a Clan
# 1                                  NaN               Join a Clan
# 2                                  NaN               Join a Clan
# 3                                  NaN               Join a Clan
# 4                                  NaN               Join a Clan
#
#   /data/achievements/0/name  /data/achievements/0/stars  \
# 0               Team Player                           3
# 1               Team Player                           3
# ...

# %%
player_data_wide_df.columns
# Out:
# Index(['/data/achievements/0/completionInfo', '/data/achievements/0/info',
#        '/data/achievements/0/name', '/data/achievements/0/stars',
#        '/data/achievements/0/target', '/data/achievements/0/value',
#        '/data/achievements/1/completionInfo', '/data/achievements/1/info',
#        '/data/achievements/1/name', '/data/achievements/1/stars',
#        ...
#        '/data/supportCards/1/rarity', '/data/tag', '/data/threeCrownWins',
#        '/data/totalDonations', '/data/totalExpPoints',
#        '/data/tournamentBattleCount', '/data/tournamentCardsWon',
#        '/data/trophies', '/data/warDayWins', '/data/wins'],
#       dtype='object', length=2329)

# %%
url_columns_to_drop = [col for col in player_data_wide_df.columns if 'Urls' in col]
player_data_wide_df.drop(columns=url_columns_to_drop, inplace=True)
player_data_wide_df.head()
# Out:
#    /data/achievements/0/completionInfo /data/achievements/0/info  \
# 0                                  NaN               Join a Clan
# 1                                  NaN               Join a Clan
# 2                                  NaN               Join a Clan
# 3                                  NaN               Join a Clan
# 4                                  NaN               Join a Clan
#
#   /data/achievements/0/name  /data/achievements/0/stars  \
# 0               Team Player                           3
# 1               Team Player                           3
# 2               Team Player                           3
# 3               Team Player                           0
# 4               Team Player                           0
#
#    /data/achievements/0/target  /data/achievements/0/value  \
# 0                            1                           4
# 1                            1                         101
# ...

# %%
info_columns_to_drop = [col for col in player_data_wide_df.columns if 'completionInfo' in col]
player_data_wide_df.drop(columns=info_columns_to_drop, inplace=True)
player_data_wide_df.head()
# Out:
#   /data/achievements/0/info /data/achievements/0/name  \
# 0               Join a Clan               Team Player
# 1               Join a Clan               Team Player
# 2               Join a Clan               Team Player
# 3               Join a Clan               Team Player
# 4               Join a Clan               Team Player
#
#    /data/achievements/0/stars  /data/achievements/0/target  \
# 0                           3                            1
# 1                           3                            1
# 2                           3                            1
# 3                           0                            1
# 4                           0                            1
#
#    /data/achievements/0/value /data/achievements/1/info  \
# 0                           4          Donate 250 cards
# 1                         101         Donate 2500 cards
# 2                          48         Donate 2500 cards
# ...

# %%
player_data_wide_df.to_csv('combined_player_tags_master.csv', index=False)
